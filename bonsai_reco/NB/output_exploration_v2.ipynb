# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import sys
import os
sys.path.append(os.path.abspath("/mnt/netapp2/Store_uni/home/usc/ie/dcr/software/hk"))

import hipy.hipy.pltext as pltext
import hipy.hipy.efit   as efit

# %load_ext autoreload
# %autoreload 2

pltext.style()

# %%
sig = pd.read_csv("/mnt/lustre/scratch/nlsas/home/usc/ie/dcr/hk/nicf_data/bonsai/testWithoutTOF_sig_vertexBONSAI.csv")

# %%
subplot = pltext.canvas(3,2,6,6)

subplot(1)
pltext.hist(sig["x"], 100, xylabels="X", stats=False, range=(-150, 150), density=True, label=f"SIG");
# pltext.hist(sig_pre["x"], 1000, xylabels="X", stats=False, range=(-150, 150), density=True, label=f"SIG PRE");
# pltext.hist(sig_pos["x"], 1000, xylabels="X", stats=False, range=(-150, 150), density=True, label=f"SIG POS");
# pltext.hist(bkg["x"], 1000, xylabels="X", stats=False, range=(-150, 150), density=True, label=f"BKG");

subplot(2)
pltext.hist(sig["y"], 100, xylabels="Y", stats=False, range=(-150, 150), density=True, label=f"SIG");
# pltext.hist(sig_pre["y"], 1000, xylabels="Y", stats=False, range=(-150, 150), density=True, label=f"SIG PRE");
# pltext.hist(sig_pos["y"], 1000, xylabels="Y", stats=False, range=(-150, 150), density=True, label=f"SIG POS");
# # pltext.hist(bkg["y"], 1000, xylabels="Y", stats=False, range=(-150, 150), density=True, label=f"bkg");

subplot(3)
pltext.hist(sig["z"], 100, xylabels="Z", stats=False, range=(-135, 135), density=True, label=f"SIG");
# pltext.hist(sig_pre["z"], 1000, xylabels="Z", stats=False, range=(-135, 135), density=True, label=f"SIG PRE");
# pltext.hist(sig_pos["z"], 1000, xylabels="Z", stats=False, range=(-135, 135), density=True, label=f"SIG POS");
# # pltext.hist(bkg["z"], 1000, xylabels="Z", stats=False, range=(-135, 135), density=True, label=f"BKG");

# %% [markdown]
# #### 1767

# %%
subplot = pltext.canvas(3)

rho = 0
phi = 0
phi_prime = phi - np.pi/2
z   = 100

source_x = rho*np.cos(phi_prime)
source_y = rho*np.sin(phi_prime)
source_z = z
source_r = 6.75

subplot(1)
plt.hist2d(sig["x"], sig["z"], bins=(100, 100));
circle = plt.Circle((source_x, source_z), source_r, color='r', label="NiCf Source");
plt.gca().add_patch(circle)
plt.xlabel("X [cm]");
plt.ylabel("Z [cm]");

subplot(2)
plt.hist2d(sig["y"], sig["z"], bins=(100, 100));
circle = plt.Circle((source_y, source_z), source_r, color='r', label="NiCf Source");
plt.gca().add_patch(circle)
plt.xlabel("Y [cm]");
plt.ylabel("Z [cm]");

subplot(3)
plt.hist2d(sig["x"], sig["y"], bins=(100, 100));
circle = plt.Circle((source_x, source_y), source_r, color='r', label="NiCf Source");
plt.gca().add_patch(circle)
plt.xlabel("X [cm]");
plt.ylabel("Y [cm]");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 subplot = pltext.canvas(3)
#       3 rho = 100-22
#       4 phi = 180 * np.pi/180
#
# NameError: name 'pltext' is not defined

# %%
pltext.hist(sig.t_vertex_rel.values, 100, stats=False, label="t_vertex_rel", xylabels="Reconstructed Vertex Relative Time [ns]");
# pltext.hist(sig.t_vertex_abs.values, 100, stats=False, label="t_vertex_abs");

# %%
sig.t_vertex_rel.values
# Out:
# array([0.5384388 , 2.55927706, 2.46511936, ..., 1.24551809, 2.53671455,
#        1.37574649])
